# %% [markdown]
# # CODECLAUSE

# %% [markdown]
# # DATA SCIENCE INTERNSHIP

# %% [markdown]
# # AUTHOR : SUSHMA S

# %% [markdown]
# # PROJECT 2 : COVID ANALYSIS

# %% [markdown]
# # Importing Statements

# %% [markdown]
# Pandas - for dataset handeling

# %% [markdown]
# Numpy - Support for Pandas and calculations

# %% [markdown]
# Matplotlib - for visualization (Platting graphas)

# %% [markdown]
# plotly - for interative plots

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# # Reading CSV file

# %%
df=pd.read_csv(r"C:\Users\welcome\Downloads\archive 2\owid-covid-data.csv")
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 325463      ZWE    Africa     Zimbabwe  2023-07-08     265604.0        0.0
# 325464      ZWE    Africa     Zimbabwe  2023-07-09     265604.0        0.0
# 325465      ZWE    Africa     Zimbabwe  2023-07-10     265604.0        0.0
# 325466      ZWE    Africa     Zimbabwe  2023-07-11     265604.0        0.0
# 325467      ZWE    Africa     Zimbabwe  2023-07-12     265604.0        0.0
#
# ...

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
df.isnull()
# Out:
#         iso_code  continent  location   date  total_cases  new_cases  \
# 0          False      False     False  False         True      False
# 1          False      False     False  False         True      False
# 2          False      False     False  False         True      False
# 3          False      False     False  False         True      False
# 4          False      False     False  False         True      False
# ...          ...        ...       ...    ...          ...        ...
# 325463     False      False     False  False        False      False
# 325464     False      False     False  False        False      False
# 325465     False      False     False  False        False      False
# 325466     False      False     False  False        False      False
# 325467     False      False     False  False        False      False
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %% [markdown]
# ## Checking whether the dataset has null values

# %%
df.isnull().sum()
# Out:
# iso_code                                        0
# continent                                   15453
# location                                        0
# date                                            0
# total_cases                                 37292
#                                             ...
# population                                      0
# excess_mortality_cumulative_absolute       314169
# excess_mortality_cumulative                314169
# excess_mortality                           314169
# excess_mortality_cumulative_per_million    314169
# Length: 67, dtype: int64

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df.tail()
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 325463      ZWE    Africa  Zimbabwe  2023-07-08     265604.0        0.0
# 325464      ZWE    Africa  Zimbabwe  2023-07-09     265604.0        0.0
# 325465      ZWE    Africa  Zimbabwe  2023-07-10     265604.0        0.0
# 325466      ZWE    Africa  Zimbabwe  2023-07-11     265604.0        0.0
# 325467      ZWE    Africa  Zimbabwe  2023-07-12     265604.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 325463              11.429        5709.0         0.0                0.286
# 325464              11.429        5709.0         0.0                0.286
# 325465               0.000        5709.0         0.0                0.000
# 325466               0.000        5709.0         0.0                0.000
# 325467               0.000        5709.0         0.0                0.000
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df.shape
# Out:
# (325468, 67)

# %%
df.nunique(axis=0)
# Out:
# iso_code                                      255
# continent                                       6
# location                                      255
# date                                         1291
# total_cases                                131945
#                                             ...
# population                                    255
# excess_mortality_cumulative_absolute        11114
# excess_mortality_cumulative                  4105
# excess_mortality                             5205
# excess_mortality_cumulative_per_million     11254
# Length: 67, dtype: int64

# %%
df.dtypes
# Out:
# iso_code                                    object
# continent                                   object
# location                                    object
# date                                        object
# total_cases                                float64
#                                             ...
# population                                 float64
# excess_mortality_cumulative_absolute       float64
# excess_mortality_cumulative                float64
# excess_mortality                           float64
# excess_mortality_cumulative_per_million    float64
# Length: 67, dtype: object

# %% [markdown]
# # PREPROCESSING THE DATA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325468 entries, 0 to 325467
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    325468 non-null  object
#  1   continent                                   310015 non-null  object
#  2   location                                    325468 non-null  object
#  3   date                                        325468 non-null  object
#  4   total_cases                                 288176 non-null  float64
#  5   new_cases                                   316492 non-null  float64
#  6   new_cases_smoothed                          315233 non-null  float64
#  7   total_deaths                                267177 non-null  float64
#  8   new_deaths                                  316540 non-null  float64
# ...

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  2.881760e+05  3.164920e+05        3.152330e+05  2.671770e+05
# mean   6.127797e+06  1.028280e+04        1.032223e+04  8.285729e+04
# std    3.788953e+07  1.143154e+05        9.796675e+04  4.261781e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    7.305000e+03  0.000000e+00        7.140000e-01  1.240000e+02
# 50%    6.392500e+04  4.000000e+00        3.214300e+01  1.226000e+03
# 75%    6.720390e+05  3.320000e+02        5.837140e+02  1.106400e+04
# max    7.679722e+08  8.401763e+06        6.402720e+06  6.950642e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  316540.000000        315310.000000            288176.000000
# mean       91.825886            92.176160             93408.270018
# std       636.019045           579.474855            143674.869661
# min         0.000000             0.000000                 0.000000
# ...

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %% [markdown]
# # Filling the null values by Median

# %%
df.fillna(df.median(), inplace=True)
# Out:
# C:\Users\welcome\AppData\Local\Temp\ipykernel_15300\3604797450.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# iso_code                                       0
# continent                                  15453
# location                                       0
# date                                           0
# total_cases                                    0
#                                            ...
# population                                     0
# excess_mortality_cumulative_absolute           0
# excess_mortality_cumulative                    0
# excess_mortality                               0
# excess_mortality_cumulative_per_million        0
# Length: 67, dtype: int64

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %% [markdown]
# # Dropping the values that are not required

# %%
not_required=['iso_code',
       'new_cases_smoothed', 
       'new_deaths_smoothed', 'total_cases_per_million',
       'new_cases_per_million', 'new_cases_smoothed_per_million',
       'total_deaths_per_million', 'new_deaths_per_million',
       'new_deaths_smoothed_per_million', 
       'hosp_patients_per_million', 'weekly_icu_admissions',
       'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
       'weekly_hosp_admissions_per_million',
       'total_tests_per_thousand', 'new_tests_per_thousand',
       'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
     'new_vaccinations_smoothed',
       'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
       'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
       'new_vaccinations_smoothed_per_million',
       'new_people_vaccinated_smoothed','excess_mortality_cumulative_per_million']

# %%
df.drop(columns=not_required,axis=1,inplace=True)
df
# Out:
#        continent     location        date  total_cases  new_cases  \
# 0           Asia  Afghanistan  2020-01-03      63925.0        0.0
# 1           Asia  Afghanistan  2020-01-04      63925.0        0.0
# 2           Asia  Afghanistan  2020-01-05      63925.0        0.0
# 3           Asia  Afghanistan  2020-01-06      63925.0        0.0
# 4           Asia  Afghanistan  2020-01-07      63925.0        0.0
# ...          ...          ...         ...          ...        ...
# 325463    Africa     Zimbabwe  2023-07-08     265604.0        0.0
# 325464    Africa     Zimbabwe  2023-07-09     265604.0        0.0
# 325465    Africa     Zimbabwe  2023-07-10     265604.0        0.0
# 325466    Africa     Zimbabwe  2023-07-11     265604.0        0.0
# 325467    Africa     Zimbabwe  2023-07-12     265604.0        0.0
#
#         total_deaths  new_deaths  reproduction_rate  icu_patients  \
# 0             1226.0         0.0               0.95          99.0
# ...

# %%
df.columns
# Out:
# Index(['continent', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients', 'total_tests', 'new_tests',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_people_vaccinated_smoothed_per_hundred',
#        'stringency_index', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index', 'population',
#        'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
#        'excess_mortality'],
#       dtype='object')

# %% [markdown]
# # MODEL_SELECTION

# %% [markdown]
# Train_test_split function from the sklearn.model_selection module. This function is commonly used in machine learning tasks to split a dataset into two or more subsets: one for training the model and another for testing its performance.Train_test_split function from sklearn.model_selection, which is used for splitting datasets.

# %%
from sklearn.model_selection import train_test_split

x=df[['total_cases', 'new_cases',
     'new_deaths', 'reproduction_rate', 'icu_patients',
       'icu_patients_per_million', 'hosp_patients', 'total_tests', 'new_tests',
       'positive_rate','new_vaccinations', 'new_people_vaccinated_smoothed_per_hundred',
       'stringency_index', 'population_density', 'median_age', 'aged_65_older',
       'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
       'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
       'male_smokers']]
y=df['total_deaths']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20)

# %%
x_train
# Out:
#         total_cases  new_cases  new_deaths  reproduction_rate  icu_patients  \
# 240584     133194.0        0.0         0.0               0.95          99.0
# 165148   44751362.0   102925.0      3569.0               0.95          99.0
# 317319    2540273.0    29413.0        91.0               1.41          99.0
# 20873        4452.0       43.0         0.0               1.10          99.0
# 99333       10536.0        0.0         0.0               0.95          99.0
# ...             ...        ...         ...                ...           ...
# 115404      45362.0        0.0         0.0               0.95          99.0
# 98348     6379634.0        0.0         0.0               0.84        2294.0
# 210535          4.0        0.0         0.0               0.95          99.0
# 39066    12534688.0    44326.0      1656.0               1.01          99.0
# 40999        7305.0        0.0         0.0               0.95          99.0
#
# ...

# %%
x_test
# Out:
#         total_cases  new_cases  new_deaths  reproduction_rate  icu_patients  \
# 318663      63925.0        4.0         0.0               0.95          21.0
# 6247         8302.0        0.0         0.0               0.95          99.0
# 136168    1703675.0        6.0         0.0               0.95          99.0
# 317449   10742234.0     3325.0         0.0               0.95          99.0
# 59753        3948.0        5.0         0.0               0.84          99.0
# ...             ...        ...         ...                ...           ...
# 86274        6890.0        0.0         0.0               0.65          99.0
# 253726     136315.0     4267.0        41.0               1.16          99.0
# 133023    4092671.0    34913.0       458.0               1.16          99.0
# 240920         16.0        0.0         0.0               0.95          99.0
# 112976      19644.0        0.0         0.0               0.05          99.0
#
# ...

# %%
y_train
# Out:
# 240584      1468.0
# 165148    727402.0
# 317319     39037.0
# 20873         96.0
# 99333         70.0
#             ...
# 115404       377.0
# 98348     116596.0
# 210535      1226.0
# 39066     312206.0
# 40999         64.0
# Name: total_deaths, Length: 260374, dtype: float64

# %%
y_test
# Out:
# 318663     1226.0
# 6247         34.0
# 136168     8790.0
# 317449    43084.0
# 59753       146.0
#            ...
# 86274       121.0
# 253726     1052.0
# 133023    93086.0
# 240920     1226.0
# 112976      238.0
# Name: total_deaths, Length: 65094, dtype: float64

# %% [markdown]
# # ACCURARY(PREDICTION) USING KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

clf=KNeighborsClassifier(n_neighbors=3)

clf.fit(x,y)

y_pred=clf.predict(x_test)
score=accuracy_score(y_test,y_pred)
print(score)
# Out:
# 0.7220327526346514

# %% [markdown]
# # GENERAL ANALYSIS OF DATA

# %% [markdown]
# ## VISUALISING DATA AS BOX PLOT

# %% [markdown]
# Subplots which means that individual box plots will be created for each column in the DataFrame and displayed in separate subplots.

# %%
df.plot(subplots=True, layout=(13,3), kind='box', figsize=(15,15), patch_artist=True)
plt.subplots_adjust(wspace=0.5);
plt.subplots_adjust(hspace=0.5)

# %% [markdown]
# ## VISUALISING DATA AS RELPLOT

# %% [markdown]
# The relplot function is primarily used to create scatter plots and other relational plots to visualize the relationship between two or more variables in a dataset.

# %%
#Considering median_age

# %%
sns.relplot(y="total_cases",x="median_age",data=df,hue="total_deaths",color='blue')

# %%
#Considering aged_65_older
sns.relplot(y="total_cases",x="aged_65_older",data=df,hue="total_deaths")

# %% [markdown]
# ## VISUALISING DATA AS SCATTERPLOT

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x=df['median_age'],y=df["total_deaths"],color='red')
plt.title('total_deaths', size=16)
plt.ylabel('count');
plt.xlabel('age');

# %% [markdown]
# ###### The above graph clearly mentions that people around 28 to 33 are affected more by Covid among median_age group

# %% [markdown]
# ##### The above graph clearly mentions that people around 5 to 10 are affected more by Covid among aged_65_older group

# %% [markdown]
# ## VISUALISING DATA AS HISTPLOT

# %% [markdown]
# histplot is another function provided by the Seaborn library for creating histograms. A histogram is a graphical representation of the distribution of a dataset, showing the frequency or count of values falling into different bins or intervals.

# %%
plt.figure(figsize=(10,4))
sns.histplot(df['life_expectancy'])
plt.title("HOSPITAL PATIENTS")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # VISUALISING DATA AS BOX PLOT

# %%
plt.figure(figsize=(20,20))
sns.boxplot(x="continent",y="total_cases",data=df)
# Out:
# <Axes: xlabel='continent', ylabel='total_cases'>

# %% [markdown]
# # VISUALISING DATA AS BARPLOT

# %%
top_countries = df.groupby('location')['total_deaths'].max().nlargest(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_countries.index, y=top_countries.values)
plt.xlabel('Country')
plt.ylabel('Total Deaths')
plt.title('Top 10 Countries with the Most COVID-19 Cases')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
top_countries = df.groupby('location')['total_cases'].max().nlargest(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_countries.index, y=top_countries.values)
plt.xlabel('Country')
plt.ylabel('Total Cases')
plt.title('Top 10 Countries with the Most COVID-19 Cases')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# ### The above figure clearly depicts that North America has more number of cases followed by Asia

# %%
sns.barplot(x=df['continent'],y=df['total_cases'])
plt.ylabel("TOTAL_CASES",fontsize=20)
plt.xlabel("COUNTRY",fontsize=20)
plt.xticks(rotation=90)
plt.show()

# %%
df.columns
# Out:
# Index(['continent', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients', 'total_tests', 'new_tests',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_people_vaccinated_smoothed_per_hundred',
#        'stringency_index', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index', 'population',
#        'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
#        'excess_mortality'],
#       dtype='object')

# %%
df1=df

# %%
cols=['continent', 'location', 'date']

# %%
df1.drop(columns=cols,axis=1,inplace=True)

# %%
df1.columns
# Out:
# Index(['total_cases', 'new_cases', 'total_deaths', 'new_deaths',
#        'reproduction_rate', 'icu_patients', 'icu_patients_per_million',
#        'hosp_patients', 'total_tests', 'new_tests', 'positive_rate',
#        'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_people_vaccinated_smoothed_per_hundred',
#        'stringency_index', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index', 'population',
#        'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
#        'excess_mortality'],
#       dtype='object')

# %% [markdown]
# # CORRELATION

# %% [markdown]
# Correlation is a statistical measure that indicates the degree to which two or more variables are related or associated. It quantifies the strength and direction of the linear relationship between two variables. In other words, correlation measures how changes in one variable are related to changes in another variable.
#
# The correlation coefficient is the common metric used to express the correlation between two variables. It ranges between -1 and +1:
#
# A correlation coefficient of +1 indicates a perfect positive correlation, meaning that when one variable increases, the other increases proportionally.
# A correlation coefficient of -1 indicates a perfect negative correlation, meaning that when one variable increases, the other decreases proportionally.
# A correlation coefficient close to 0 suggests a weak or no linear correlation between the variables.

# %% [markdown]
# # calculating correlation matrix using kendall

# %%
# calculate correlation matrix
## using non-parametric test of correlation (kendall), since some features are binary
corrs = df.select_dtypes(include=np.number).corr(method = 'kendall')

# plot clustered heatmap of correlations
sns.clustermap(corrs, cmap='coolwarm', center=0);
# Out:
# C:\Users\welcome\anaconda3\lib\site-packages\scipy\stats\_stats_py.py:5278: RuntimeWarning: overflow encountered in longlong_scalars
#   (2 * xtie * ytie) / m + x0 * y0 / (9 * m * (size - 2)))

# %% [markdown]
# # calculating correlation matrix using SPEARMAN

# %%
# calculate correlation matrix
## using non-parametric test of correlation (kendall), since some features are binary
corrs = df.select_dtypes(include=np.number).corr(method = 'spearman')

# plot clustered heatmap of correlations
sns.clustermap(corrs, cmap='coolwarm', center=0);

# %% [markdown]
# ### * From the Correlation matrix , it is found that the DIFFERENT AGE GROUPS has the highest positive correlation followed by TOTAL BOOSTERS AND VACCINATIONS.

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x=df1['total_cases'],y=df1['total_deaths'],data=df1)
plt.title("correlation between the total cases and total deaths",fontdict={'color':'purple'},size=15)
plt.show()

# %% [markdown]
# # PLOTTING USING PIE CHART

# %%
country_cases = df.groupby('location')['total_cases'].max().reset_index()
country_cases = country_cases.sort_values(by='total_cases', ascending=False)
top_countries = country_cases.head(10)

plt.figure(figsize=(10, 6))
plt.pie(top_countries['total_cases'], labels=top_countries['location'],
        autopct='%1.1f%%', startangle=140, colors=plt.cm.Set3.colors)
plt.title('Top 10 Countries with the Most COVID-19 Cases')
plt.axis('equal')
plt.show()
