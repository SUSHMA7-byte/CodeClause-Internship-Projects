# %% [markdown]
# # CODECLAUSE

# %% [markdown]
# # AUTHOR : SUSHMA S

# %% [markdown]
# # DATA SCIENCE INTERNSHIP

# %% [markdown]
# # PROJECT 1 : CUSTOMER_CHURN_RATE_ANALYSIS

# %% [markdown]
# ### IMPORTING PACKAGES

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### READING DATASET

# %%
df=pd.read_csv(r"C:\Users\welcome\Downloads\Telecom_Churn_Rate_Dataset.csv")

# %% [markdown]
# ### VIEWING DATASET

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# ### Viewing the first ten rows of the dataset

# %%
df.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... StreamingTV  \
# ...

# %% [markdown]
# ### Viewing the last fifteen rows of the dataset

# %%
df.tail(15)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7028  9281-CEDRU  Female              0     Yes         No      68
# 7029  2235-DWLJU  Female              1      No         No       6
# 7030  0871-OPBXW  Female              0      No         No       2
# 7031  3605-JISKB    Male              1     Yes         No      55
# 7032  6894-LFHLY    Male              1      No         No       1
# 7033  9767-FFLEM    Male              0      No         No      38
# 7034  0639-TSIQW  Female              0      No         No      67
# 7035  8456-QDAVC    Male              0      No         No      19
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7037  2569-WGERO  Female              0      No         No      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# ...

# %% [markdown]
# ### Viewing the names of the columns and its datatype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  numAdminTickets  \
# count    7043.000000  7043.000000     7043.000000      7043.000000
# mean        0.162147    32.371149       64.761692         0.515689
# std         0.368612    24.559481       30.090047         1.275299
# min         0.000000     0.000000       18.250000         0.000000
# 25%         0.000000     9.000000       35.500000         0.000000
# 50%         0.000000    29.000000       70.350000         0.000000
# 75%         0.000000    55.000000       89.850000         0.000000
# max         1.000000    72.000000      118.750000         5.000000
#
#        numTechTickets
# count     7043.000000
# mean         0.419566
# std          1.250117
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          9.000000

# %% [markdown]
# ### CHECKING FOR NULL VALUES

# %%
# Finding the columns with null values
# Converting Total Charges to a numerical data type.
df.TotalCharges = pd.to_numeric(df.TotalCharges, errors='coerce')
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# numAdminTickets      0
# numTechTickets       0
# Churn                0
# dtype: int64

# %%
#Removing missing values 
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# numAdminTickets     0
# numTechTickets      0
# Churn               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.size
# Out:
# 161736

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# numAdminTickets       int64
# numTechTickets        int64
# Churn                object
# dtype: object

# %% [markdown]
# ### Getting the unique values per column

# %%
for i in df.columns:
    print(f"Unique {i}'s count: {df[i].nunique()}")
    print(f"{df[i].unique()}\n")
# Out:
# Unique customerID's count: 7032
# ['7590-VHVEG' '5575-GNVDE' '3668-QPYBK' ... '4801-JZAZL' '8361-LTMKD'
#  '3186-AJIEK']
#
# Unique gender's count: 2
# ['Female' 'Male']
#
# Unique SeniorCitizen's count: 2
# [0 1]
#
# Unique Partner's count: 2
# ['Yes' 'No']
#
# Unique Dependents's count: 2
# ['No' 'Yes']
#
# Unique tenure's count: 72
# [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
#
# Unique PhoneService's count: 2
# ['No' 'Yes']
#
# Unique MultipleLines's count: 3
# ['No phone service' 'No' 'Yes']
#
# Unique InternetService's count: 3
# ['DSL' 'Fiber optic' 'No']
#
# Unique OnlineSecurity's count: 3
# ['No' 'Yes' 'No internet service']
#
# Unique OnlineBackup's count: 3
# ['Yes' 'No' 'No internet service']
#
# Unique DeviceProtection's count: 3
# ['No' 'Yes' 'No internet service']
#
# ...

# %%
df.shape
# Out:
# (7032, 23)

# %%
df.nunique(axis=1)
# Out:
# 0       11
# 1       11
# 2       11
# 3       13
# 4       11
#         ..
# 7038    11
# 7039    12
# 7040    12
# 7041    12
# 7042    12
# Length: 7032, dtype: int64

# %%
df.nunique(axis=0)
# Out:
# customerID          7032
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                72
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1584
# TotalCharges        6530
# numAdminTickets        6
# numTechTickets        10
# Churn                  2
# dtype: int64

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'numAdminTickets',
#        'numTechTickets', 'Churn'],
#       dtype='object')

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# # DATA VISUALIZATION

# %%
plt.title("COMAPRISON BETWEEN TENURE AND GENDER")
sns.barplot(y="tenure",x="gender",data=df,color='red')
# Out:
# <Axes: title={'center': 'COMAPRISON BETWEEN TENURE AND GENDER'}, xlabel='gender', ylabel='tenure'>

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'numAdminTickets',
#        'numTechTickets', 'Churn'],
#       dtype='object')

# %%
plt.figure(figsize=(8,4))
sns.barplot(x=df['gender'],y=df["TotalCharges"],color='pink')
plt.title('comparison between gender and TotalCharges', size=16)
plt.ylabel('TotalCharges');
plt.xlabel('gender');

# %%
plt.figure(figsize=(8,4))
sns.histplot(y=df['gender'],x=df["Churn"],color='green')
plt.title('COMAPRISON BETWEEN CHURN AND GENDER', size=16)
plt.ylabel('gender');
plt.xlabel('Churn');

# %%
# calculate correlation matrix
## using non-parametric test of correlation (kendall), since some features are binary
corrs = df.select_dtypes(include=np.number).corr(method = 'kendall')

# plot clustered heatmap of correlations
sns.clustermap(corrs, cmap='coolwarm', center=0);

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'numAdminTickets',
#        'numTechTickets', 'Churn'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %%
df.hist(bins=50, figsize=(15,20),color="green");

# %%
plt.figure(figsize=(15,15))
sns.boxenplot(x=df['numAdminTickets'],y=df['numTechTickets'],data=df)
plt.title("correlation between the numAdminTickets and numTechTickets",fontdict={'color':'purple'},size=16)
plt.show()

# %%
df.skew()
# Out:
# SeniorCitizen      1.831103
# tenure             0.237731
# MonthlyCharges    -0.222103
# TotalCharges       0.961642
# numAdminTickets    2.451173
# numTechTickets     3.373292
# dtype: float64

# %%
df["Churn"][df["Churn"]=="No"].groupby(by=df["gender"]).count()
# Out:
# gender
# Female    2544
# Male      2619
# Name: Churn, dtype: int64

# %%
df["Churn"][df["Churn"]=="Yes"].groupby(by=df["gender"]).count()
# Out:
# gender
# Female    939
# Male      930
# Name: Churn, dtype: int64

# %%
colors = ['blue','violet']
dx = (df['SeniorCitizen'].value_counts()*100.0 /len(df))\
.plot.pie(autopct='%.1f%%', labels = ['No', 'Yes'],figsize =(5,5), fontsize = 12,colors=colors )                                                                            
dx.set_ylabel('Senior Citizens',fontsize = 15)
dx.set_title('% of Senior Citizens', fontsize = 15)
# Out:
# Text(0.5, 1.0, '% of Senior Citizens')

# %%
colors = ['red','green']
dx = (df['Dependents'].value_counts()*100.0 /len(df))\
.plot.pie(autopct='%.1f%%', labels = ['No', 'Yes'],figsize =(5,5), fontsize = 12,colors=colors )                                                                            
dx.set_ylabel('Dependents',fontsize = 15)
dx.set_title('% of Dependents', fontsize = 15)
# Out:
# Text(0.5, 1.0, '% of Dependents')

# %%
colors = ['yellow','orange']
dx = (df['Partner'].value_counts()*100.0 /len(df))\
.plot.pie(autopct='%.1f%%', labels = ['No', 'Yes'],figsize =(5,5), fontsize = 12,colors=colors )                                                                            
dx.set_ylabel('Partner',fontsize = 15)
dx.set_title('% of Partner', fontsize = 15)
# Out:
# Text(0.5, 1.0, '% of Partner')

# %%
colors = ['green','brown']
dx = (df['PhoneService'].value_counts()*100.0 /len(df))\
.plot.pie(autopct='%.1f%%', labels = ['No', 'Yes'],figsize =(5,5), fontsize = 12,colors=colors )                                                                            
dx.set_ylabel('PhoneService',fontsize = 15)
dx.set_title('% of PhoneService', fontsize = 15)
# Out:
# Text(0.5, 1.0, '% of PhoneService')

# %%
colors = ['yellow','violet']
dx = (df['Churn'].value_counts()*100.0 /len(df))\
.plot.pie(autopct='%.1f%%', labels = ['No', 'Yes'],figsize =(5,5), fontsize = 12,colors=colors )                                                                            
dx.set_ylabel('Churn',fontsize = 15)
dx.set_title('% of Churn', fontsize = 15)
# Out:
# Text(0.5, 1.0, '% of Churn')

# %%
service = ['PhoneService','MultipleLines','InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies']

fig, axes = plt.subplots(nrows = 3,ncols = 3,figsize = (15,12))
for i, item in enumerate(service):
    if i < 3:
        ax = df[item].value_counts().plot(kind = 'bar',ax=axes[i,0],rot = 0,color = 'red')
        
    elif i >=3 and i < 6:
        ax = df[item].value_counts().plot(kind = 'bar',ax=axes[i-3,1],rot = 0,color = 'green')
        
    elif i < 9:
        ax = df[item].value_counts().plot(kind = 'bar',ax=axes[i-6,2],rot = 0,color = 'blue')
    ax.set_title(item)

# %%
sns.boxplot(x = df.Churn, y = df.tenure,palette=colors)
# Out:
# <Axes: xlabel='Churn', ylabel='tenure'>

# %%
column_name_to_drop = "customerID"
df.drop(column_name_to_drop, axis=1, inplace=True)

# %%
column_name_to_drop1 = "PaymentMethod"
df.drop(column_name_to_drop1, axis=1, inplace=True)

# %%
df['gender'] = df['gender'].replace(['Male', 'Female'],[0,1])

# %%
df=df.replace(['Yes', 'No','No phone service','DSL','Fiber optic','No internet service'],[0,1,2,3,4,5])

# %%
df=df.replace(['One year','Month-to-month','Two year'],[1,0,2])

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'MonthlyCharges',
#        'TotalCharges', 'numAdminTickets', 'numTechTickets', 'Churn'],
#       dtype='object')

# %% [markdown]
# # VISUALISING THE DATA USING HISTOGRAM

# %%
df.hist(bins=50, figsize=(50,40),color='red');

# %% [markdown]
# # MODEL_SELECTION

# %% [markdown]
# ###### Train_test_split function from the sklearn.model_selection module. This function is commonly used in machine learning tasks to split a dataset into two or more subsets: one for training the model and another for testing its performance.Train_test_split function from sklearn.model_selection, which is used for splitting datasets.

# %%
from sklearn.model_selection import train_test_split

x=df[[ 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
        'MonthlyCharges', 'TotalCharges', 'numAdminTickets',
       'numTechTickets']]

y=df[['Churn']]

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20)

# %%
x_train
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 6631       0              0        0           1      25             0
# 4465       0              0        1           1      31             1
# 5327       1              0        0           0      30             0
# 2120       1              0        0           0      55             0
# 1285       0              1        0           1       7             0
# ...      ...            ...      ...         ...     ...           ...
# 538        1              0        0           1      69             0
# 4596       0              0        1           1      18             0
# 2825       0              0        1           1      15             0
# 6561       0              0        1           1       9             0
# 5338       1              0        0           1      37             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
x_test
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 1283       1              0        0           1      72             0
# 3075       0              0        0           1      71             0
# 5938       0              1        0           0      34             0
# 1741       0              0        1           1      16             0
# 116        1              0        1           1      36             1
# ...      ...            ...      ...         ...     ...           ...
# 4591       1              0        1           1      10             0
# 5426       0              0        0           1      51             0
# 4600       0              0        0           0      56             0
# 1427       0              1        1           1      44             0
# 1840       0              0        0           0      65             0
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
y_train
# Out:
#       Churn
# 6631      1
# 4465      1
# 5327      1
# 2120      1
# 1285      0
# ...     ...
# 538       1
# 4596      1
# 2825      1
# 6561      1
# 5338      1
#
# [5625 rows x 1 columns]

# %%
y_test
# Out:
#       Churn
# 1283      1
# 3075      1
# 5938      1
# 1741      1
# 116       1
# ...     ...
# 4591      1
# 5426      1
# 4600      1
# 1427      1
# 1840      0
#
# [1407 rows x 1 columns]

# %% [markdown]
# # ACCURACY PREDICTION

# %%
# Running logistic regression model
from sklearn.linear_model import LogisticRegression
clf= LogisticRegression()
result=clf.fit(x_train,y_train)
from sklearn import metrics
pred_test = clf.predict(x_test)

# Print the prediction accuracy
print (metrics.accuracy_score(y_test, pred_test))
# Out:
# 0.8479033404406539

# %%
df.hist(bins=50, figsize=(15,20),color="green");

# %%
c=['green','blue','red','orange','brown','violet']
dw= pd.Series(clf.coef_[0],index=x.columns.values)
print (dw.sort_values(ascending = False)[:10].plot(kind='bar',color=c))
# Out:
# Axes(0.125,0.11;0.775x0.77)
